# 48   49               SHIP CONSTRUCTION   Cavan
# 49   50               SHIP CONSTRUCTION   Cavan
#
#                                   Scheme/Project Name  No. of Units  \
# 0                    Carrigbrook, Tullow Road, Carlow            16
# 1                    Carrigbrook, Tullow Road, Carlow            13
# 2                  Granville Court, Granby Row,Carlow             4
# 3                                 Ardattin, Co Carlow             6
# 4                              Brownbog, Hackettstown             1
# 5                            St. Mary’s Court, Carlow             4
# 6                   Drumphea, Garryhill, Bagenalstown             1
# 7                        Constable Hill, Hackettstown             1
# 8                           Old Leighlin Road, Carlow             1
# 9                      5 & 6 Staplestown Road, Carlow             2
# 10                                      Bahana, Glynn             5
# 11                             Barrack Street, Carlow             7
# 12            2a Chapel Street, Graiguecullen, Carlow             1
# 13           24 Church Street, Graiguecullen, Carlow              1
# 14  Breens Shop Units, Main Street, Borris, Co. Ca...             2
# 15                                 Pound Lane, Borris             9
# 16                      Gleann na Bearu, Bagenalstown             6
# 17          41-42 Dublin Street & Cox's Lane, Carlow             12
# 18                      Gleann na Bearu, Bagenalstown             6
# 19                      Gleann na Bearu, Bagenalstown            10
# 20      Gleann na Bearu, Royal Oak Road, Bagenalstown             6
# 21                   Homefield, Blackbog Road, Carlow             3
# 22                                   Bog Lane, Borris             1
# 23       Ballickmoyler, Graigcullen, Carlow (Phase 1)            22
# 24       Ballickmoyler, Graigcullen, Carlow (Phase 2)            35
# 25  Cois Dara, Tullow Road, Chapelstown, Carlow  (...            17
# 26  Cois Dara, Tullow Road, Chapelstown, Carlow  (...            15
# 27  Cois Dara, Tullow Road, Chapelstown, Carlow  (...            21
# 28  Cois Dara, Tullow Road, Chapelstown, Carlow  (...            10
# 29  Granite Court, Ballyknockan, Fenagh, Co Carlow...             8
# 30  Mill Race, Paupish Lane, Carlow, Co. Carlow (P...             6
# 31                    Rivercourt,  Carlow  (Phase 2)*            19
# 32  Sli Na Ri, Moneybeg, Bagenalstown, Co. Carlow ...             7
# 33  Sli Na Ri, Moneybeg, Bagenalstown, Co. Carlow ...            12
# 34        The Millrace, Burrin, Co. Carlow (Phase 1)*            22
# 35              Ashgrove, Derrylurgan, Ballyjamesduff             4
# 36              Woodlands, Killyfinla, Ballyjamesduff             4
# 37              Woodlands, Killyfinla, Ballyjamesduff             8
# 38              Woodlands, Killyfinla, Ballyjamesduff            10
# 39              Woodlands, Killyfinla, Ballyjamesduff            10
# 40                          Mullaghduff, Ballyconnell            10
# 41                          Mullaghduff, Ballyconnell            10
# 42                          Mullaghduff, Ballyconnell            11
# 43                    Abhainn Dubh, Rosehill, Mullagh             4
# 44                      Kilnavara Heights, Cavan Town             2
# 45                        Derrylurgan, Ballyjamesduff            12
# 46                               Corstruce, Ballinagh             4
# 47                               Main Street, Mullagh            19
# 48                     Elm Grove, Main St, Cavan Town            13
# 49                              Cavan Road, Ballinagh            15
#
#                              Approved Housing Body  \
# 0                                             *N/A
# 1                                             *N/A
# 2                                             *N/A
# 3                                             *N/A
# 4                                             *N/A
# 5                                             *N/A
# 6                                             *N/A
# 7                                             *N/A
# 8                                             *N/A
# 9                                             *N/A
# 10                                            *N/A
# 11                                            *N/A
# 12                                            *N/A
# 13                                            *N/A
# 14                                            *N/A
# 15                                            *N/A
# 16                                            *N/A
# 17                                            *N/A
# 18                                            *N/A
# 19                                            *N/A
# 20                                         Respond
# 21            Carlow Voluntary Housing Association
# 22                                            *N/A
# 23  Co - Operative Housing Ireland Society Limited
# 24  Co - Operative Housing Ireland Society Limited
# 25                       Tuath Housing Association
# 26                       Tuath Housing Association
# 27                       Tuath Housing Association
# 28                       Tuath Housing Association
# 29  Co - Operative Housing Ireland Society Limited
# 30                       Tuath Housing Association
# 31  Co - Operative Housing Ireland Society Limited
# 32  Co - Operative Housing Ireland Society Limited
# 33  Co - Operative Housing Ireland Society Limited
# 34  Co - Operative Housing Ireland Society Limited
# 35                                            *N/A
# 36                                            *N/A
# 37                                            *N/A
# 38                                            *N/A
# 39                                            *N/A
# 40                                            *N/A
# 41                                            *N/A
# 42                                            *N/A
# 43                                            *N/A
# 44                                            *N/A
# 45                                             NaN
# 46                                            *N/A
# 47                                            *N/A
# 48                                            *N/A
# 49                                            *N/A
#
#                             Stage 1 Capital Appraisal Stage 2 Pre Planning   \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN                   NaN
# 11  Stage 1 approved Q3-2020, outline design and c...                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14  Stage 1 approved Q1-2022, outline design and c...                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17  Stage 1 approved Q2-2022, outline design and c...                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 25                                                NaN                   NaN
# 26                                                NaN                   NaN
# 27                                                NaN                   NaN
# 28                                                NaN                   NaN
# 29                                                NaN                   NaN
# 30                                                NaN                   NaN
# 31                                                NaN                   NaN
# 32                                                NaN                   NaN
# 33                                                NaN                   NaN
# 34                                                NaN                   NaN
# 35                                                NaN                   NaN
# 36                                                NaN                   NaN
# 37                                                NaN                   NaN
# 38                                                NaN                   NaN
# 39                                                NaN                   NaN
# 40                                                NaN                   NaN
# 41                                                NaN                   NaN
# 42                                                NaN                   NaN
# 43                                                NaN                   NaN
# 44                                                NaN                   NaN
# 45  Stage 1 approved Q4-2021, outline design and c...                   NaN
# 46                                                NaN                   NaN
# 47                                                NaN                   NaN
# 48                                                NaN                   NaN
# 49                                                NaN                   NaN
#
#    Stage 3 Pre Tender design  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN
# 31                       NaN
# 32                       NaN
# 33                       NaN
# 34                       NaN
# 35                       NaN
# 36                       NaN
# 37                       NaN
# 38                       NaN
# 39                       NaN
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43                       NaN
# 44                       NaN
# 45                       NaN
# 46                       NaN
# 47                       NaN
# 48                       NaN
# 49                       NaN
#
#    Stage 4 Tender Report or Final Turnkey/CALF approval  On Site Completed
# 0                                                 NaN        NaN   Q4-2021
# 1                                                 NaN        NaN   Q2-2021
# 2                                                 NaN        NaN   Q4-2021
# 3   Stage 4 approved Q2-2019, the scheme is fully ...        NaN       NaN
# 4                                                 NaN    Q1-2020       NaN
# 5   Stage 4 approved Q2-2021, the scheme is fully ...        NaN       NaN
# 6   Stage 4 approved Q2-2021, the scheme is fully ...        NaN       NaN
# 7   Stage 4 approved Q4-2021, the scheme is fully ...        NaN       NaN
# 8   Stage 4 approved Q2-2022, the scheme is fully ...        NaN       NaN
# 9   Stage 4 approved Q4-2021, the scheme is fully ...        NaN       NaN
# 10  Stage 4 approved Q2-2022, the scheme is fully ...        NaN       NaN
# 11                                                NaN        NaN       NaN
# 12  Stage 4 approved Q2-2022, the scheme is fully ...        NaN       NaN
# 13  Stage 4 approved Q2-2022, the scheme is fully ...        NaN       NaN
# 14                                                NaN        NaN       NaN
# 15                                                NaN        NaN   Q2-2021
# 16  Stage 4 approved Q3-2021, the scheme is fully ...        NaN       NaN
# 17                                                NaN        NaN       NaN
# 18  Stage 4 approved Q3-2021, the scheme is fully ...        NaN       NaN
# 19  Stage 4 approved Q3-2021, the scheme is fully ...        NaN       NaN
# 20                                                NaN    Q4-2020       NaN
# 21                                                NaN        NaN   Q2-2021
# 22                                                NaN        NaN   Q2-2022
# 23                                                NaN        NaN   Q2-2021
# 24                                                NaN        NaN   Q4-2021
# 25                                                NaN        NaN   Q3-2021
# 26                                                NaN        NaN   Q4-2021
# 27                                                NaN        NaN   Q1-2022
# 28                                                NaN        NaN   Q2-2022
# 29                                                NaN    Q2-2021       NaN
# 30                                                NaN        NaN   Q2-2021
# 31                                                NaN        NaN   Q1-2022
# 32                                                NaN    Q2-2021       NaN
# 33                                                NaN    Q2-2021       NaN
# 34                                                NaN        NaN   Q4-2021
# 35                                                NaN        NaN   Q4-2021
# 36                                                NaN    Q1-2021       NaN
# 37  Stage 4 approved Q2-2020, the scheme is fully ...        NaN       NaN
# 38  Stage 4 approved Q2-2020, the scheme is fully ...        NaN       NaN
# 39  Stage 4 approved Q2-2020, the scheme is fully ...        NaN       NaN
# 40                                                NaN    Q2-2021       NaN
# 41                                                NaN    Q2-2021       NaN
# 42                                                NaN    Q2-2021       NaN
# 43                                                NaN        NaN   Q4-2021
# 44                                                NaN    Q1-2022       NaN
# 45                                                NaN        NaN       NaN
# 46                                                NaN        NaN   Q2-2021
# 47                                                NaN    Q4-2020       NaN
# 48  Stage 4 approved Q4-2021, the scheme is fully ...        NaN       NaN
# 49                                                NaN    Q2-2021       NaN

# %%
df.shape
# Out:
# (1566, 12)

# %%
missing_counts = df.isnull().sum()
print("Missing values in each column:")
print(missing_counts)
# Out:
# Missing values in each column:
# No.                                                        0
# Funding Programme                                          0
# LA                                                         0
# Scheme/Project Name                                        0
# No. of Units                                               0
# Approved Housing Body                                     42
# Stage 1 Capital Appraisal                               1412
# Stage 2 Pre Planning                                    1446
# Stage 3 Pre Tender design                               1515
# Stage 4 Tender Report or Final Turnkey/CALF approval    1237
# On Site                                                 1156
# Completed                                               1064
# dtype: int64

# %%
# For my objectives I don't need the columns Stage 1, Stage 2, Stage 3, Stage 4 so I will drop these
df_1 = df.drop(columns = ['Stage 1 Capital Appraisal', 'Stage 2 Pre Planning ','Stage 3 Pre Tender design','Stage 4 Tender Report or Final Turnkey/CALF approval'])

# %%
df_1.shape
# Out:
# (1566, 8)

# %%
missing_counts = df_1.isnull().sum()
print("Missing values in each column:")
print(missing_counts)
# Out:
# Missing values in each column:
# No.                         0
# Funding Programme           0
# LA                          0
# Scheme/Project Name         0
# No. of Units                0
# Approved Housing Body      42
# On Site                  1156
# Completed                1064
# dtype: int64

# %%
# There is 42 missing values under 'Approved Housing Body', which is 2.7% of the data
# As removing this data will not make a significant impact I will drop these columns. 

df_1.dropna(subset=['Approved Housing Body'], inplace = True)
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1524 entries, 0 to 1565
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   No.                    1524 non-null   int64
#  1   Funding Programme      1524 non-null   object
#  2   LA                     1524 non-null   object
#  3   Scheme/Project Name    1524 non-null   object
#  4   No. of Units           1524 non-null   int64
#  5   Approved Housing Body  1524 non-null   object
#  6   On Site                408 non-null    object
#  7   Completed              491 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 107.2+ KB

# %%
# Now there is 1156 missing values in 'On site' and 1064 in 'completed'
# Removing these would have significant impacts on the data
#I know that null values means 'No' so I will replace null values in these columns with 'No'

df_1['On Site'].fillna('No', inplace = True)
df_1['Completed'].fillna('No', inplace = True)

# %%
df_1.head()
# Out:
#    No.               Funding Programme      LA  \
# 0    1       SHIP CONSTRUCTION TURNKEY  Carlow
# 1    2       SHIP CONSTRUCTION TURNKEY  Carlow
# 2    3       SHIP CONSTRUCTION TURNKEY  Carlow
# 3    4  SHIP CONSTRUCTION SINGLE STAGE  Carlow
# 4    5  SHIP CONSTRUCTION SINGLE STAGE  Carlow
#
#                   Scheme/Project Name  No. of Units Approved Housing Body  \
# 0    Carrigbrook, Tullow Road, Carlow            16                  *N/A
# 1    Carrigbrook, Tullow Road, Carlow            13                  *N/A
# 2  Granville Court, Granby Row,Carlow             4                  *N/A
# 3                 Ardattin, Co Carlow             6                  *N/A
# 4              Brownbog, Hackettstown             1                  *N/A
#
#    On Site Completed
# 0       No   Q4-2021
# 1       No   Q2-2021
# 2       No   Q4-2021
# 3       No        No
# 4  Q1-2020        No
