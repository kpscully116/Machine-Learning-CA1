# %% [markdown]
# Dataset: https://opendata.housing.gov.ie/dataset/social-housing-construction-status-report-q2-2022
# Social Housing Construction Status Report Q2 2022
# The latest Construction Status Report shows that 8,247 social homes are currently onsite with an additional 12,327 homes at design and tender stage. In Quarter 2 2022, 118 new construction schemes, (1,647 homes) were added to the pipeline. In total the Construction Status Report provides details on 27,006 new build social homes across 1,566 schemes.

# %%
# import dataset "Social Housing Construction Status Report Q2 2022" downloaded from Department of Housing, Local Government and Heritage

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('social-housing-construction-status-report-q2-2022.csv', encoding='windows-1252')

# %% [markdown]
# ## Understanding and Cleaning the Data

# %%
df.tail(50)
# Out:
#        No.                      Funding Programme       LA  \
# 1516  1517         SHIP CONSTRUCTION SINGLE STAGE  Wicklow
# 1517  1518         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1518  1519         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1519  1520         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1520  1521         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1521  1522         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1522  1523         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1523  1524         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1524  1525         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1525  1526         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1526  1527         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1527  1528         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1528  1529         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1529  1530         SHIP CONSTRUCTION DESIGN BUILD  Wicklow
# 1530  1531                      SHIP CONSTRUCTION  Wicklow
# 1531  1532                      SHIP CONSTRUCTION  Wicklow
# 1532  1533                      SHIP CONSTRUCTION  Wicklow
# 1533  1534                      SHIP CONSTRUCTION  Wicklow
# 1534  1535                      SHIP CONSTRUCTION  Wicklow
# 1535  1536                      SHIP CONSTRUCTION  Wicklow
# 1536  1537                      SHIP CONSTRUCTION  Wicklow
# 1537  1538                      SHIP CONSTRUCTION  Wicklow
# 1538  1539                      SHIP CONSTRUCTION  Wicklow
# 1539  1540                      SHIP CONSTRUCTION  Wicklow
# 1540  1541               CAS CONSTRUCTION TURNKEY  Wicklow
# 1541  1542          CAS CONSTRUCTION SINGLE STAGE  Wicklow
# 1542  1543                           CALF Turnkey  Wicklow
# 1543  1544                           CALF Turnkey  Wicklow
# 1544  1545                           CALF Turnkey  Wicklow
# 1545  1546                           CALF Turnkey  Wicklow
# 1546  1547                           CALF Turnkey  Wicklow
# 1547  1548                           CALF Turnkey  Wicklow
# 1548  1549                           CALF Turnkey  Wicklow
# 1549  1550                           CALF Turnkey  Wicklow
# 1550  1551                           CALF Turnkey  Wicklow
# 1551  1552                           CALF Turnkey  Wicklow
# 1552  1553                           CALF Turnkey  Wicklow
# 1553  1554                           CALF Turnkey  Wicklow
# 1554  1555                           CALF Turnkey  Wicklow
# 1555  1556                           CALF Turnkey  Wicklow
# 1556  1557                           CALF Turnkey  Wicklow
# 1557  1558                           CALF Turnkey  Wicklow
# 1558  1559                           CALF Turnkey  Wicklow
# 1559  1560                           CALF Turnkey  Wicklow
# 1560  1561                           CALF Turnkey  Wicklow
# 1561  1562                           CALF Turnkey  Wicklow
# 1562  1563                           CALF Turnkey  Wicklow
# 1563  1564                           CALF Turnkey  Wicklow
# 1564  1565                           CALF Turnkey  Wicklow
# 1565  1566  PUBLIC PRIVATE PARTNERSHIP (Bundle 3)  Wicklow
#
#                                     Scheme/Project Name  No. of Units  \
# 1516                    Ballynerrin Upper, Wicklow Town            10
# 1517                         Merrymeeting View, Rathnew            46
# 1518                                 Shillelagh Phase 4            20
# 1519                     Ard na Greine, West Ward, Bray            31
# 1520                         Avondale Heights, Rathdrum            20
# 1521                 Sheehan Court, Back Street, Arklow             7
# 1522                           Three Trouts, Greystones            41
# 1523                       Greenhill Road, Wicklow Town            36
# 1524                    Cedar Court, Schools Road, Bray            14
# 1525                   Coolattin Oaks, Carnew (Phase 4)             8
# 1526       Rathnew, Merrymeeting, Co. Wicklow (Phase 2)            21
# 1527                      Tinahely, Lugduff, Co Wicklow            20
# 1528                                   Carrigoona, Bray            15
# 1529                                Lott Lane, Kilcoole            80
# 1530       Delaney Park, Emoclew Road, Arklow (Phase 3)            10
# 1531               10A & 10 B Castle Villas, Greystones             2
# 1532       Delaney Park, Emoclew Road, Arklow (Phase 2)            37
# 1533                  Blackhills, Glenealy, Co. Wicklow             2
# 1534  Age Friendly Apartments at Main St, Kilcoole, ...             4
# 1535                Mill Road, Killincarrig, Greystones             2
# 1536                  Carraig Eden, Greysones (Phase 3)            14
# 1537               Kilbride Lane, Bray (Murphy's Lands)            19
# 1538                     Knockroe, Delgany, Co. Wicklow             2
# 1539          Ard Rua, Barndarraig, Arklow, Co. Wicklow            12
# 1540                      Rathcoran Square, Baltinglass             8
# 1541                 Hollybrook Park, Bray, Co. Wicklow             4
# 1542  Adelaide Apartments, St Laurence’s Terrace, Br...            18
# 1543  Avondale Grange, Ballygannon, Rathdrum, Co. Wi...            36
# 1544  Fairgreen Manor, Dunlavin, Co. Wicklow (Phase 1)*            40
# 1545           Heatherside, Vale Road, Arklow (Phase 1)            11
# 1546           Heatherside, Vale Road, Arklow (Phase 2)            12
# 1547           Heatherside, Vale Road, Arklow (Phase 3)            17
# 1548           Heatherside, Vale Road, Arklow (Phase 4)            18
# 1549          Heatherside, Vale Road, Arklow (Phase 5)*            30
# 1550  Heatherside, Vale Road, Arklow, Co. Wicklow (P...            15
# 1551  Heatherside, Vale Road, Arklow, Co. Wicklow (P...            10
# 1552  Heatherside, Vale Road, Arklow, Co. Wicklow (P...             3
# 1553   Lower Main Street, Arklow, Co. Wicklow (Phase 1)             4
# 1554   Main Street, Blessington, Co. Wicklow (Phase 1)*            22
# 1555   Main Street, Blessington, Co. Wicklow (Phase 2)*            36
# 1556  Oak Springs, Rathdrum, County Wicklow  (Phase 1)*             5
# 1557  Phase 2, Southern Cross, Bray, Co. Wicklow (Ph...            80
# 1558  Phase 3, Southern Cross, Bray, Co. Wicklow (Ph...            80
# 1559  Rathcoran House, Baltinglass, Co. Wicklow (Pha...            24
# 1560  Rathcoran House, Baltinglass, Co. Wicklow (Pha...            16
# 1561     Southern Cross, Bray, Co. Wicklow\n (Phase 1)*            30
# 1562     Southern Cross, Bray, Co. Wicklow\n (Phase 2)*            18
# 1563  The Old Rectory, Blessington, Co. Wicklow (Pha...            45
# 1564       Vartry Wood, Ashford, Co. Wicklow (Phase 1)*            16
# 1565             Burgage More, Blessington, Co. Wicklow           106
#
#                                Approved Housing Body  \
# 1516                                            *N/A
# 1517                                            *N/A
# 1518                                            *N/A
# 1519                                            *N/A
# 1520                                            *N/A
# 1521                                            *N/A
# 1522                                            *N/A
# 1523                                            *N/A
# 1524                                            *N/A
# 1525                                            *N/A
# 1526                                            *N/A
# 1527                                            *N/A
# 1528                                            *N/A
# 1529                                            *N/A
# 1530                                            *N/A
# 1531                                            *N/A
# 1532                                            *N/A
# 1533                                            *N/A
# 1534                                            *N/A
# 1535                                            *N/A
# 1536                                            *N/A
# 1537                                            *N/A
# 1538                                            *N/A
# 1539                                            *N/A
# 1540                         Peter McVerry Trust Ltd
# 1541         St. John of God Housing Association Ltd
# 1542                                         Respond
# 1543                                         Respond
# 1544        Circle Voluntary Housing Association Ltd
# 1545                       Tuath Housing Association
# 1546                       Tuath Housing Association
# 1547                       Tuath Housing Association
# 1548                       Tuath Housing Association
# 1549                       Tuath Housing Association
# 1550                       Tuath Housing Association
# 1551                       Tuath Housing Association
# 1552                       Tuath Housing Association
# 1553             Clanmil Housing Association Ireland
# 1554        Circle Voluntary Housing Association Ltd
# 1555        Circle Voluntary Housing Association Ltd
# 1556                       Tuath Housing Association
# 1557  Co - Operative Housing Ireland Society Limited
# 1558  Co - Operative Housing Ireland Society Limited
# 1559                                         Respond
# 1560                                         Respond
# 1561  Co - Operative Housing Ireland Society Limited
# 1562  Co - Operative Housing Ireland Society Limited
# 1563  Co - Operative Housing Ireland Society Limited
# 1564                                   Clúid Housing
# 1565                                            *N/A
#
#                               Stage 1 Capital Appraisal  \
# 1516                                                NaN
# 1517                                                NaN
# 1518                                                NaN
# 1519                                                NaN
# 1520                                                NaN
# 1521                                                NaN
# 1522                                                NaN
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
# 1528                                                NaN
# 1529                                                NaN
# 1530                                                NaN
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535                                                NaN
# 1536                                                NaN
# 1537                                                NaN
# 1538                                                NaN
# 1539  Stage 1 approved Q2-2021, outline design and c...
# 1540                                                NaN
# 1541                                                NaN
# 1542                                                NaN
# 1543                                                NaN
# 1544                                                NaN
# 1545                                                NaN
# 1546                                                NaN
# 1547                                                NaN
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551                                                NaN
# 1552                                                NaN
# 1553                                                NaN
# 1554                                                NaN
# 1555                                                NaN
# 1556                                                NaN
# 1557                                                NaN
# 1558                                                NaN
# 1559                                                NaN
# 1560                                                NaN
# 1561                                                NaN
# 1562                                                NaN
# 1563                                                NaN
# 1564                                                NaN
# 1565                                                NaN
#
#                                   Stage 2 Pre Planning   \
# 1516                                                NaN
# 1517                                                NaN
# 1518                                                NaN
# 1519                                                NaN
# 1520                                                NaN
# 1521                                                NaN
# 1522  Stage 2 approved Q1-2022, full design/tender b...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527  Stage 2 approved Q4-2021, full design/tender b...
# 1528  Stage 2 approved Q2-2022, full design/tender b...
# 1529  Stage 2 approved Q2-2022, full design/tender b...
# 1530                                                NaN
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534  Stage 2 approved Q3-2021, full design/tender b...
# 1535                                                NaN
# 1536  Stage 2 approved Q4-2021, full design/tender b...
# 1537                                                NaN
# 1538  Stage 2 approved Q1-2022, full design/tender b...
# 1539                                                NaN
# 1540                                                NaN
# 1541                                                NaN
# 1542                                                NaN
# 1543                                                NaN
# 1544                                                NaN
# 1545                                                NaN
# 1546                                                NaN
# 1547                                                NaN
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551                                                NaN
# 1552                                                NaN
# 1553                                                NaN
# 1554                                                NaN
# 1555                                                NaN
# 1556                                                NaN
# 1557                                                NaN
# 1558                                                NaN
# 1559                                                NaN
# 1560                                                NaN
# 1561                                                NaN
# 1562                                                NaN
# 1563                                                NaN
# 1564                                                NaN
# 1565                                            Q4-2021
#
#                               Stage 3 Pre Tender design  \
# 1516                                                NaN
# 1517                                                NaN
# 1518                                                NaN
# 1519                                                NaN
# 1520                                                NaN
# 1521                                                NaN
# 1522                                                NaN
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
# 1528                                                NaN
# 1529                                                NaN
# 1530                                                NaN
# 1531  Stage 3 approved Q1-2022, the scheme is now ap...
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 1535  Stage 3 approved Q1-2022, the scheme is now ap...
# 1536                                                NaN
# 1537                                                NaN
# 1538                                                NaN
# 1539                                                NaN
# 1540                                                NaN
# 1541                                                NaN
# 1542                                                NaN
# 1543                                                NaN
# 1544                                                NaN
# 1545                                                NaN
# 1546                                                NaN
# 1547                                                NaN
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551                                                NaN
# 1552                                                NaN
# 1553                                                NaN
# 1554                                                NaN
# 1555                                                NaN
# 1556                                                NaN
# 1557                                                NaN
# 1558                                                NaN
# 1559                                                NaN
# 1560                                                NaN
# 1561                                                NaN
# 1562                                                NaN
# 1563                                                NaN
# 1564                                                NaN
# 1565                                                NaN
#
#      Stage 4 Tender Report or Final Turnkey/CALF approval  On Site Completed
# 1516  Stage 4 approved Q2-2022, the scheme is fully ...        NaN       NaN
# 1517                                                NaN        NaN   Q2-2021
# 1518  Stage 4 approved Q2-2022, the scheme is fully ...        NaN       NaN
# 1519                                                NaN        NaN   Q1-2022
# 1520                                                NaN    Q3-2021       NaN
# 1521                                                NaN    Q2-2021       NaN
# 1522                                                NaN        NaN       NaN
# 1523                                                NaN    Q2-2021       NaN
# 1524                                                NaN    Q1-2022       NaN
# 1525                                                NaN        NaN   Q1-2021
# 1526  Stage 4 approved Q1-2022, the scheme is fully ...        NaN       NaN
# 1527                                                NaN        NaN       NaN
# 1528                                                NaN        NaN       NaN
# 1529                                                NaN        NaN       NaN
# 1530                                                NaN        NaN   Q1-2022
# 1531                                                NaN        NaN       NaN
# 1532                                                NaN        NaN   Q4-2021
# 1533                                                NaN    Q4-2021       NaN
# 1534                                                NaN        NaN       NaN
# 1535                                                NaN        NaN       NaN
# 1536                                                NaN        NaN       NaN
# 1537                                                NaN        NaN   Q2-2021
# 1538                                                NaN        NaN       NaN
# 1539                                                NaN        NaN       NaN
# 1540                                                NaN        NaN   Q2-2021
# 1541  Stage 4 approved Q3-2019, the scheme is fully ...        NaN       NaN
# 1542                                                NaN    Q2-2021       NaN
# 1543                                                NaN    Q2-2021       NaN
# 1544                                                NaN        NaN   Q3-2021
# 1545                                                NaN        NaN   Q2-2022
# 1546                                                NaN    Q2-2021       NaN
# 1547                                                NaN    Q2-2021       NaN
# 1548                                                NaN    Q2-2021       NaN
# 1549                                                NaN    Q2-2021       NaN
# 1550                                                NaN        NaN   Q4-2021
# 1551                                                NaN        NaN   Q1-2022
# 1552                                                NaN    Q4-2020       NaN
# 1553                                                NaN    Q2-2021       NaN
# 1554                                            Q2-2022        NaN       NaN
# 1555                                            Q2-2022        NaN       NaN
# 1556                                                NaN    Q3-2020       NaN
# 1557                                                NaN    Q4-2020       NaN
# 1558                                                NaN    Q4-2020       NaN
# 1559                                                NaN        NaN   Q2-2021
# 1560                                                NaN        NaN   Q3-2021
# 1561                                                NaN        NaN   Q2-2022
# 1562                                                NaN    Q2-2021       NaN
# 1563                                                NaN    Q3-2020       NaN
# 1564                                                NaN    Q2-2021       NaN
# 1565                                                NaN        NaN       NaN

# %%
df.shape
# Out:
# (1566, 12)

# %%
# I now know the shape and contents of the data.
# I see missing information in columns so I will further investigate this.
missing_counts = df.isnull().sum()
print("Missing values in each column:")
print(missing_counts)
# Out:
# Missing values in each column:
# No.                                                        0
# Funding Programme                                          0
# LA                                                         0
# Scheme/Project Name                                        0
# No. of Units                                               0
# Approved Housing Body                                     42
# Stage 1 Capital Appraisal                               1412
# Stage 2 Pre Planning                                    1446
# Stage 3 Pre Tender design                               1515
# Stage 4 Tender Report or Final Turnkey/CALF approval    1237
# On Site                                                 1156
# Completed                                               1064
# dtype: int64

# %%
# For my objectives I don't need the columns Stage 1, Stage 2, Stage 3, Stage 4 so I will drop these.
# These have a substantial amount of missing information.
df_1 = df.drop(columns = ['Stage 1 Capital Appraisal', 'Stage 2 Pre Planning ','Stage 3 Pre Tender design','Stage 4 Tender Report or Final Turnkey/CALF approval'])

# %%
df_1.shape
# Out:
# (1566, 8)

# %%
# Now these are dropped, I will investigate what remains missing
missing_counts = df_1.isnull().sum()
print("Missing values in each column:")
print(missing_counts)
# Out:
# Missing values in each column:
# No.                         0
# Funding Programme           0
# LA                          0
# Scheme/Project Name         0
# No. of Units                0
# Approved Housing Body      42
# On Site                  1156
# Completed                1064
# dtype: int64

# %%
# There is 42 missing values under 'Approved Housing Body', which is 2.7% of the data
# As removing this data will not make a significant impact I will drop these rows. 

df_1.dropna(subset=['Approved Housing Body'], inplace = True)
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1524 entries, 0 to 1565
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   No.                    1524 non-null   int64
#  1   Funding Programme      1524 non-null   object
#  2   LA                     1524 non-null   object
#  3   Scheme/Project Name    1524 non-null   object
#  4   No. of Units           1524 non-null   int64
#  5   Approved Housing Body  1524 non-null   object
#  6   On Site                408 non-null    object
#  7   Completed              491 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 107.2+ KB

# %%
# Now there is 1156 missing values in 'On site' and 1064 in 'completed'
# Removing these would have significant impacts on the data
# I know that null values means 'No' so I will replace null values in these columns with 'No'

df_1['On Site'].fillna('No', inplace = True)
df_1['Completed'].fillna('No', inplace = True)

# %%
df_1.head()
# Out:
#    No.               Funding Programme      LA  \
# 0    1       SHIP CONSTRUCTION TURNKEY  Carlow
# 1    2       SHIP CONSTRUCTION TURNKEY  Carlow
# 2    3       SHIP CONSTRUCTION TURNKEY  Carlow
# 3    4  SHIP CONSTRUCTION SINGLE STAGE  Carlow
# 4    5  SHIP CONSTRUCTION SINGLE STAGE  Carlow
#
#                   Scheme/Project Name  No. of Units Approved Housing Body  \
# 0    Carrigbrook, Tullow Road, Carlow            16                  *N/A
# 1    Carrigbrook, Tullow Road, Carlow            13                  *N/A
# 2  Granville Court, Granby Row,Carlow             4                  *N/A
# 3                 Ardattin, Co Carlow             6                  *N/A
# 4              Brownbog, Hackettstown             1                  *N/A
#
#    On Site Completed
# 0       No   Q4-2021
# 1       No   Q2-2021
# 2       No   Q4-2021
# 3       No        No
# 4  Q1-2020        No

# %%
missing_counts = df_1.isnull().sum()
print("Missing values in each column:")
print(missing_counts)
# Out:
# Missing values in each column:
# No.                      0
# Funding Programme        0
# LA                       0
# Scheme/Project Name      0
# No. of Units             0
# Approved Housing Body    0
# On Site                  0
# Completed                0
# dtype: int64

# %%
# I now have no missing data. Approved Housing Authority does have "*N/A" as a feature, but Iknow this means there is no Approved Housing Authority.
# I want to further understand the values in each columns

for column in df_1.columns:
    print(f"value counts for: {column}")
    print(df_1[column].value_counts(dropna=False))
    print()
# Out:
# value counts for: No.
# No.
# 1       1
# 1047    1
# 1056    1
# 1055    1
# 1054    1
#        ..
# 520     1
# 518     1
# 517     1
# 516     1
# 1566    1
# Name: count, Length: 1524, dtype: int64
#
# value counts for: Funding Programme
# Funding Programme
# CALF Turnkey                             447
# SHIP CONSTRUCTION                        374
# SHIP CONSTRUCTION TURNKEY                255
# CAS CONSTRUCTION                         109
# SHIP DIALOG                               76
# SHIP CONSTRUCTION SINGLE STAGE            58
# SHIP CONSTRUCTION DESIGN BUILD            45
# SHIP CONSTRUCTION RENEWAL                 43
# CALF Construction                         30
# CAS CONSTRUCTION TURNKEY                  25
# REGENERATION                              22
# PUBLIC PRIVATE PARTNERSHIP (Bundle 2)     14
# CAS CONSTRUCTION RENEWAL                  13
# CAS CONSTRUCTION SINGLE STAGE              6
# PUBLIC PRIVATE PARTNERSHIP (Bundle 3)      6
# PUBLIC PRIVATE PARTNERSHIP (Bundle 1)      1
# Name: count, dtype: int64
#
# value counts for: LA
# LA
# Cork County      106
# Cork City         92
# Dublin City       76
# Limerick          74
# Kildare           72
# Louth             71
# Wexford           68
# Tipperary         65
# Meath             64
# Wicklow           63
# South Dublin      63
# Westmeath         55
# Laois             53
# Galway County     53
# Kerry             53
# Kilkenny          43
# Fingal            42
# DLR               41
# Monaghan          40
# Cavan             37
# Carlow            35
# Donegal           35
# Waterford         32
# Clare             32
# Mayo              31
# Offaly            31
# Galway City       30
# Leitrim           19
# Longford          18
# Roscommon         15
# Sligo             15
# Name: count, dtype: int64
#
# value counts for: Scheme/Project Name
# Scheme/Project Name
# Kilcarbery JV Social                               24
# Meenane, Watergrasshill                             5
# Seaville, Ursuline Convent                          4
# Woodlands, Killyfinla, Ballyjamesduff               4
# Mullaghduff, Ballyconnell                           4
#                                                    ..
# Ballybanemor Road, Ballybrit, Galway (Phase 2)      1
# Ballybanemor Road, Ballybrit, Galway (Phase 1)*     1
# 111 Upper Newcastle Road, Galway City               1
# Doughiska, Galway City                              1
# Burgage More, Blessington, Co. Wicklow              1
# Name: count, Length: 1369, dtype: int64
#
# value counts for: No. of Units
# No. of Units
# 4      108
# 1      106
# 2      104
# 6       76
# 10      71
#       ...
# 102      1
# 117      1
# 78       1
# 57       1
# 106      1
# Name: count, Length: 101, dtype: int64
#
# value counts for: Approved Housing Body
# Approved Housing Body
# *N/A                                              892
# Tuath Housing Association                         131
# Clúid Housing                                     130
# Respond                                            89
# Co - Operative Housing Ireland Society Limited     68
#                                                  ...
# Marillac Housing Association                        1
# Praxis Housing Association                          1
# Daughters Of Charity Of St Vincent De Paul          1
# Simon Community : North West Simon                  1
# Wexford Womens’ Refuge CLG                          1
# Name: count, Length: 71, dtype: int64
#
# value counts for: On Site
# On Site
# No         1116
# Q2-2021      74
# Q3-2020      52
# Q4-2020      50
# Q1-2021      34
# Q3-2021      34
# Q4-2021      33
# Q1-2020      28
# Q1-2022      25
# Q4-2019      19
# Q1-2019      11
# Q2-2022      11
# Q3-2019      10
# Q2-2020       9
# Q2-2019       7
# Q4-2018       3
# Q4-2017       3
# Q3-2018       3
# Q1-2018       1
# Q2-2018       1
# Name: count, dtype: int64
#
# value counts for: Completed
# Completed
# No         1033
# Q4-2021     135
# Q2-2021     123
# Q2-2022      87
# Q1-2021      53
# Q3-2021      47
# Q1-2022      46
# Name: count, dtype: int64

# %%
# My data is clean and ready for model building
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1524 entries, 0 to 1565
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   No.                    1524 non-null   int64
#  1   Funding Programme      1524 non-null   object
#  2   LA                     1524 non-null   object
#  3   Scheme/Project Name    1524 non-null   object
#  4   No. of Units           1524 non-null   int64
#  5   Approved Housing Body  1524 non-null   object
#  6   On Site                1524 non-null   object
#  7   Completed              1524 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 107.2+ KB

# %% [markdown]
# ## Data Pre-processing

# %%
from sklearn import preprocessing

# %%
# Encode categorical features to numerical features
label_encoders = {}
for col in df_1.select_dtypes(include=[object]).columns:
    le = preprocessing.LabelEncoder()
    df_1[col] = le.fit_transform(df_1[col])
    label_encoders[col] = le                   # Store encoders if needed later

# %%
df_1.tail()
# Out:
#        No.  Funding Programme  LA  Scheme/Project Name  No. of Units  \
# 1561  1562                  1  30                 1207            30
# 1562  1563                  1  30                 1208            18
# 1563  1564                  1  30                 1289            45
# 1564  1565                  1  30                 1324            16
# 1565  1566                  8  30                  317           106
#
#       Approved Housing Body  On Site  Completed
# 1561                     19        0          4
# 1562                     19        9          0
# 1563                     19       13          0
# 1564                     18        9          0
# 1565                      0        0          0

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1524 entries, 0 to 1565
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   No.                    1524 non-null   int64
#  1   Funding Programme      1524 non-null   int32
#  2   LA                     1524 non-null   int32
#  3   Scheme/Project Name    1524 non-null   int32
#  4   No. of Units           1524 non-null   int64
#  5   Approved Housing Body  1524 non-null   int32
#  6   On Site                1524 non-null   int32
#  7   Completed              1524 non-null   int32
# dtypes: int32(6), int64(2)
# memory usage: 71.4 KB

# %%
max_value = df_1['No. of Units'].max()
print(max_value)
# Out:
# 163

# %%
mid_value = df_1['No. of Units'].median()
print(mid_value)
# Out:
# 11.0

# %%
# convert target variable income to categorical
bins = [-1,11,1000]
labels = ['0-11','12+']

df_1['No. of Units Category'] = pd.cut(df_1['No. of Units'], bins=bins, labels=labels)

# %%
# Count how many times each class occurs
cat_value = df_1['No. of Units Category'].value_counts()
print(cat_value)
# Out:
# No. of Units Category
# 0-11    765
# 12+     759
# Name: count, dtype: int64

# %%
df_1.shape
# Out:
# (1524, 9)

# %%
missing_counts = df_1.isnull().sum()
print("Missing values in each column:")
print(missing_counts)
# Out:
# Missing values in each column:
# No.                      0
# Funding Programme        0
# LA                       0
# Scheme/Project Name      0
# No. of Units             0
# Approved Housing Body    0
# On Site                  0
# Completed                0
# No. of Units Category    0
# dtype: int64

# %%
df_1 = df_1.drop(columns = ['No. of Units'])
df_1.head()
# Out:
#    No.  Funding Programme  LA  Scheme/Project Name  Approved Housing Body  \
# 0    1                 14   0                  347                      0
# 1    2                 14   0                  347                      0
# 2    3                 14   0                  708                      0
# 3    4                 13   0                  151                      0
# 4    5                 13   0                  309                      0
#
#    On Site  Completed No. of Units Category
# 0        0          6                   12+
# 1        0          3                   12+
# 2        0          6                  0-11
# 3        0          0                  0-11
# 4        3          0                  0-11

# %%
# Define feature variables
X = df_1.drop('No. of Units Category',axis=1)

# Define target variable
y = df_1['No. of Units Category']

# %% [markdown]
# ## Model Building and Evaluation

# %%
# Importing train-test-split 
from sklearn.model_selection import train_test_split

# %%
# Importing machine models from sklearn library
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# Importing classification report confusion matrix and accuracy score from sklearn metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
results_90 = []
results_85 = []
results_75 = []

models = {
        "k-Nearest Neighbors": KNeighborsClassifier(n_neighbors=5),
        "Decision Tree": DecisionTreeClassifier(random_state=41),
        "Random Forest": RandomForestClassifier(n_estimators=100, random_state=41),
        "Logistic Regression": LogisticRegression(max_iter=1000, random_state=41),
        "Support Vector Machine": SVC(kernel='linear', random_state=41)}

def apply_models_90(X, y):
        # Assign training and test data
        X_train_90, X_test_90, y_train_90, y_test_90 = train_test_split(X, y, train_size=0.90, random_state = 41)
    
        for model_name, model_instance in models.items():
        
            #train the model
            model_instance.fit(X_train_90, y_train_90)
            
            # Predict on the test set
            y_pred = model_instance.predict(X_test_90)
        
            # Calculate performance metrics
            accuracy = accuracy_score(y_test_90, y_pred)
            report = classification_report(y_test_90, y_pred, output_dict=True)
            precision = report['weighted avg']['precision']
            recall = report['weighted avg']['recall']
            f1_score = report['weighted avg']['f1-score']
            
            results_90.append([model_name, accuracy, precision, recall, f1_score])

def apply_models_85(X, y):
        # Assign training and test data
        X_train_85, X_test_85, y_train_85, y_test_85 = train_test_split(X, y, train_size=0.85, random_state = 41)
    
        for model_name, model_instance in models.items():
        
            #train the model
            model_instance.fit(X_train_85, y_train_85)
            
            # Predict on the test set
            y_pred = model_instance.predict(X_test_85)
        
            # Calculate performance metrics
            accuracy = accuracy_score(y_test_85, y_pred)
            report = classification_report(y_test_85, y_pred, output_dict=True)
            precision = report['weighted avg']['precision']
            recall = report['weighted avg']['recall']
            f1_score = report['weighted avg']['f1-score']
            
            results_85.append([model_name, accuracy, precision, recall, f1_score])


def apply_models_75(X, y):
        # Assign training and test data
        X_train_75, X_test_75, y_train_75, y_test_75 = train_test_split(X, y, train_size=0.75, random_state = 41)
    
        for model_name, model_instance in models.items():
        
            #train the model
            model_instance.fit(X_train_75, y_train_75)
            
            # Predict on the test set
            y_pred = model_instance.predict(X_test_75)
        
            # Calculate performance metrics
            accuracy = accuracy_score(y_test_75, y_pred)
            report = classification_report(y_test_75, y_pred, output_dict=True)
            precision = report['weighted avg']['precision']
            recall = report['weighted avg']['recall']
            f1_score = report['weighted avg']['f1-score']
            # Add resukts to dataframe for printing
            results_75.append([model_name, accuracy, precision, recall, f1_score])
# Apply the models
apply_models_90(X, y)
apply_models_85(X, y)
apply_models_75(X, y)
# Create columns in dataframe for visual ease
results_df_90 = pd.DataFrame(results_90, columns=["Model", "Accuracy", "Precision", "Recall", "F1 Score"])
results_df_85 = pd.DataFrame(results_85, columns=["Model", "Accuracy", "Precision", "Recall", "F1 Score"])
results_df_75 = pd.DataFrame(results_75, columns=["Model", "Accuracy", "Precision", "Recall", "F1 Score"])
# print the dataframes
print("Model Performance Metrics (90% Training set):")
print(results_df_90)
print("Model Performance Metrics (85% Training set):")
print(results_df_85)
print("Model Performance Metrics (75% Training set):")
print(results_df_75)
# Out:
# Model Performance Metrics (90% Training set):
#                     Model  Accuracy  Precision    Recall  F1 Score
# 0     k-Nearest Neighbors  0.555556   0.555556  0.555556  0.555556
# 1           Decision Tree  0.647059   0.649408  0.647059  0.646455
# 2           Random Forest  0.692810   0.694030  0.692810  0.692679
# 3     Logistic Regression  0.640523   0.644503  0.640523  0.639168
# 4  Support Vector Machine  0.633987   0.636219  0.633987  0.633361
# Model Performance Metrics (85% Training set):
#                     Model  Accuracy  Precision    Recall  F1 Score
# 0     k-Nearest Neighbors  0.563319   0.562959  0.563319  0.562450
# 1           Decision Tree  0.655022   0.656063  0.655022  0.654930
# 2           Random Forest  0.685590   0.686978  0.685590  0.685446
# 3     Logistic Regression  0.663755   0.666725  0.663755  0.663088
# 4  Support Vector Machine  0.624454   0.634395  0.624454  0.619795
# Model Performance Metrics (75% Training set):
#                     Model  Accuracy  Precision    Recall  F1 Score
# 0     k-Nearest Neighbors  0.582677   0.583017  0.582677  0.582522
# 1           Decision Tree  0.677165   0.677905  0.677165  0.676970
# 2           Random Forest  0.687664   0.687672  0.687664  0.687625
# 3     Logistic Regression  0.653543   0.653532  0.653543  0.653519
# 4  Support Vector Machine  0.614173   0.615241  0.614173  0.612828

# %% [markdown]
# ## Cross Validation on full dataset

# %%
# Cross-validation for accuracy on the full dataset
cv_results = []
for model_name, model_instance in models.items():
    cv_scores = cross_val_score(model_instance, X, y, cv=5, scoring='accuracy')
    cv_results.append([model_name, cv_scores.mean()])

# Display cross-validation results
cv_results_df = pd.DataFrame(cv_results, columns=["Model", "Mean CV Accuracy"])
print("\nCross-Validation Accuracy Scores:")
print(cv_results_df)
# Out:
# Cross-Validation Accuracy Scores:
#                     Model  Mean CV Accuracy
# 0     k-Nearest Neighbors          0.526931
# 1           Decision Tree          0.582720
# 2           Random Forest          0.581383
# 3     Logistic Regression          0.598490
# 4  Support Vector Machine          0.562368

# %% [markdown]
# ## Hyper-parameter: GridSearchCV

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=41),
    "Decision Tree": DecisionTreeClassifier(random_state=41),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=41),
    "k-Nearest Neighbors": KNeighborsClassifier(n_neighbors=5),
    "Support Vector Machine": SVC(kernel='linear', random_state=41),
   }

# %%
# Define hyperparameter grids for each classifier
param_grids = {
    "Logistic Regression": {
        "C": [0.1, 1, 10],
        "solver": ['lbfgs', 'liblinear'],
        "penalty": ['l2']
    },
    "Decision Tree": {
        "max_depth": [None, 10, 20, 30],

    },
    "Random Forest": {
        "n_estimators": [50, 100, 200],
        "max_depth": [None, 10, 20, 30],

    },
    "k-Nearest Neighbors": {
        "n_neighbors": [3, 5, 7, 9],
        "algorithm": ['auto', 'ball_tree', 'kd_tree', 'brute']     #The "algorithm" parameter in the KNeighborsClassifier controls how the nearest neighbors search is performed. It determines the method used to compute distances between points in the feature space and find the nearest neighbors. There are four options for the "algorithm"
    },
    "Support Vector Machine": {
        "C": [0.1, 1, 10],
        "kernel": ['linear', 'rbf'],
        "gamma": ['scale', 'auto']
    },
}

# %%
X_train_75, X_test_75, y_train_75, y_test_75 = train_test_split(X, y, train_size=0.75, random_state = 41)

# Apply GridSearchCV for each models and evaluate performance metric scores
results = []
for model_name, model_instance in models.items():
    print(f"Running GridSearchCV for {model_name}...")
    grid_search = GridSearchCV(estimator=model_instance, param_grid=param_grids[model_name], cv = 5, n_jobs = -1, verbose = 2)
    grid_search.fit(X_train_75, y_train_75)
    
    # Best model from grid search
    best_model = grid_search.best_estimator_
    
    # Predict on the test set with the best model
    y_pred = best_model.predict(X_test_75)
    
    # Calculate performance metrics
    accuracy = accuracy_score(y_test_75, y_pred)
    report = classification_report(y_test_75, y_pred, output_dict=True)
    precision = report['weighted avg']['precision']
    recall = report['weighted avg']['recall']
    f1_score = report['weighted avg']['f1-score']
    
    # Append results
    results.append([model_name, accuracy, precision, recall, f1_score, grid_search.best_params_])
# Out:
# Running GridSearchCV for Logistic Regression...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Running GridSearchCV for Decision Tree...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Running GridSearchCV for Random Forest...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Running GridSearchCV for k-Nearest Neighbors...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Running GridSearchCV for Support Vector Machine...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Running GridSearchCV for Neural Network...
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
# Convert results to DataFrame for easy viewing
results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1 Score", "Best Parameters"])
print("Model Performance Metrics on Test Set after GridSearchCV:")
print(results_df)
# Out:
# Model Performance Metrics on Test Set after GridSearchCV:
#                     Model  Accuracy  Precision    Recall  F1 Score  \
# 0     Logistic Regression  0.656168   0.656164  0.656168  0.656125
# 1           Decision Tree  0.677165   0.677905  0.677165  0.676970
# 2           Random Forest  0.695538   0.695675  0.695538  0.695530
# 3     k-Nearest Neighbors  0.582677   0.583017  0.582677  0.582522
# 4  Support Vector Machine  0.614173   0.615241  0.614173  0.612828
# 5          Neural Network  0.593176   0.607524  0.593176  0.580809
#
#                                      Best Parameters
# 0  {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 1                                {'max_depth': None}
# 2            {'max_depth': None, 'n_estimators': 50}
# 3            {'algorithm': 'auto', 'n_neighbors': 5}
# 4   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 5  {'activation': 'relu', 'hidden_layer_sizes': (...

# %%
# Cross-validation for accuracy on the full dataset using best models
cv_results = []
for model_name, model_instances in models.items():
    # Get the best model from GridSearchCV
    grid_search = GridSearchCV(estimator=model_instances, param_grid=param_grids[model_name], cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train_75, y_train_75)
    best_model = grid_search.best_estimator_
    
    cv_scores = cross_val_score(best_model, X, y, cv=5, scoring='accuracy')
    cv_results.append([model_name, cv_scores.mean()])
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
# Display cross-validation results
cv_results_df = pd.DataFrame(cv_results, columns=["Model", "Mean CV Accuracy"])
print("\nCross-Validation Accuracy Scores after GridSearchCV:")
print(cv_results_df)
# Out:
# Cross-Validation Accuracy Scores after GridSearchCV:
#                     Model  Mean CV Accuracy
# 0     Logistic Regression          0.597834
# 1           Decision Tree          0.582720
# 2           Random Forest          0.578745
# 3     k-Nearest Neighbors          0.526931
# 4  Support Vector Machine          0.559745
